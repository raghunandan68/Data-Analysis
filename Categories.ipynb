# %%
import pandas as pd

# %%
data=pd.read_csv("loan_approved.csv")
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  601 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              599 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           582 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              592 non-null    float64
#  9   Loan_Amount_Term        600 non-null    float64
#  10  Credit_History          564 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
len(data['Loan_ID'].unique())
# Out:
# 614

# %%
data['Gender'].unique() #categorical - nominal
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
data['Married'].unique() #categorical - nominal
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data['Dependents'].unique() #categorical - ordinal
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
data['Education'].unique() #categorical - nominal
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
data['Self_Employed'].unique() #categorical - nominal
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data['ApplicantIncome'].unique() #continuous column
# Out:
# array([ 5849,  4583,  3000,  2583,  6000,  5417,  2333,  3036,  4006,
#        12841,  3200,  2500,  3073,  1853,  1299,  4950,  3596,  3510,
#         4887,  2600,  7660,  5955,  3365,  3717,  9560,  2799,  4226,
#         1442,  3750,  4166,  3167,  4692,  3500, 12500,  2275,  1828,
#         3667,  3748,  3600,  1800,  2400,  3941,  4695,  3410,  5649,
#         5821,  2645,  4000,  1928,  3086,  4230,  4616, 11500,  2708,
#         2132,  3366,  8080,  3357,  3029,  2609,  4945,  5726, 10750,
#         7100,  4300,  3208,  1875,  4755,  5266,  1000,  3333,  3846,
#         2395,  1378,  3988,  2366,  8566,  5695,  2958,  6250,  3273,
#         4133,  3620,  6782,  2484,  1977,  4188,  1759,  4288,  4843,
#        13650,  4652,  3816,  3052, 11417,  7333,  3800,  2071,  5316,
#         2929,  3572,  7451,  5050, 14583,  2214,  5568, 10408,  5667,
#         2137,  2957,  3692, 23803,  3865, 10513,  6080, 20166,  2014,
# ...

# %%
data['CoapplicantIncome'].unique()
# Out:
# array([0.00000000e+00, 1.50800000e+03, 2.35800000e+03, 4.19600000e+03,
#        1.51600000e+03, 2.50400000e+03, 1.52600000e+03, 1.09680000e+04,
#        7.00000000e+02, 1.84000000e+03, 8.10600000e+03, 2.84000000e+03,
#        1.08600000e+03, 3.50000000e+03, 5.62500000e+03, 1.91100000e+03,
#        1.91700000e+03, 2.92500000e+03, 2.25300000e+03, 1.04000000e+03,
#        2.08300000e+03, 3.36900000e+03, 1.66700000e+03, 3.00000000e+03,
#        2.06700000e+03, 1.33000000e+03, 1.45900000e+03, 7.21000000e+03,
#        1.66800000e+03, 1.21300000e+03, 2.33600000e+03, 3.44000000e+03,
#        2.27500000e+03, 1.64400000e+03, 1.16700000e+03, 1.59100000e+03,
#        2.20000000e+03, 2.25000000e+03, 2.85900000e+03, 3.79600000e+03,
#        3.44900000e+03, 4.59500000e+03, 2.25400000e+03, 3.06600000e+03,
#        1.87500000e+03, 1.77400000e+03, 4.75000000e+03, 3.02200000e+03,
#        4.00000000e+03, 2.16600000e+03, 1.88100000e+03, 2.53100000e+03,
# ...

# %%
data['CoapplicantIncome'].isna().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
sns.histplot(data['CoapplicantIncome'])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %%
data['LoanAmount'].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
data['Loan_Amount_Term'].unique() #discrete column
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
data['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
data['Property_Area'].unique() #categorical - nominal
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
data['Loan_Status (Approved)'].unique() #categorical - nominal
# Out:
# array(['Y', 'N'], dtype=object)

# %%
data['LoanAmount'].isna().sum()
# Out:
# np.int64(22)

# %%
data['Gender']=data['Gender'].fillna(data['Gender'].mode())

# %%
data['LoanAmount'].median()
# Out:
# 128.0

# %%
data['LoanAmount'].mean()
# Out:
# np.float64(146.41216216216216)

# %%
data['LoanAmount']=data['LoanAmount'].fillna(data['LoanAmount'].mean())

# %%
data.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
sns.countplot(x='Dependents',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
data.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
data.Education.value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
sns.countplot(x='Education',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
data.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
sns.countplot(x='Self_Employed',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
data.Loan_Amount_Term.value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
sns.countplot(x='Loan_Amount_Term',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='count'>

# %%
data.Credit_History.value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
sns.countplot(x='Credit_History',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Credit_History', ylabel='count'>

# %%
data.Property_Area.value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
sns.countplot(x='Property_Area',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
mean_appin=data['ApplicantIncome'].mean()
sd_appin=data['ApplicantIncome'].std()
print(mean_appin)
print(sd_appin)
# Out:
# 5403.459283387622
# 6109.041673387174

# %%
data['ApplicantIncome'].head()
# Out:
# 0    5849
# 1    4583
# 2    3000
# 3    2583
# 4    6000
# Name: ApplicantIncome, dtype: int64

# %%
z1=(5849-mean_appin)/sd_appin
print(z1)
z2=(4583-mean_appin)/sd_appin
print(z2)
z3=(3000-mean_appin)/sd_appin
print(z3)
z4=(2583-mean_appin)/sd_appin
print(z4)
z5=(6000-mean_appin)/sd_appin
print(z5)
# Out:
# 0.07293135984867927
# -0.13430245319192863
# -0.3934265653904138
# -0.4616860440933629
# 0.09764882096173755

# %%
data['ApplicantIncome'].max()
# Out:
# 81000

# %%
print('Applicant Income Column skew : ',data['ApplicantIncome'].skew())
# Out:
# Applicant Income Column skew :  6.539513113994625

# %%
print('Applicant Income Column kurtosis : ',data['ApplicantIncome'].kurtosis())
# Out:
# Applicant Income Column kurtosis :  60.54067593369113

# %%
print('Loan Amount Column skew : ',data['LoanAmount'].skew())
print('Loan Amount Column kurtosis : ',data['LoanAmount'].kurtosis())
# Out:
# Loan Amount Column skew :  2.726601144105299
# Loan Amount Column kurtosis :  10.896456468091559

# %%
print('CoApplicantIncome Column skew : ',data['CoapplicantIncome'].skew())
print('CoApplicantIncome Column kurtosis : ',data['CoapplicantIncome'].kurtosis())
# Out:
# CoApplicantIncome Column skew :  7.491531216657306
# CoApplicantIncome Column kurtosis :  84.95638421103374

# %%
df1=pd.get_dummies(data['Property_Area'],prefix='Property_Area',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Property_Area'],axis=1)
print(data)
# Out:
#      Property_Area_Semiurban  Property_Area_Urban
# 0                      False                 True
# 1                      False                False
# 2                      False                 True
# 3                      False                 True
# 4                      False                 True
# ..                       ...                  ...
# 609                    False                False
# 610                    False                False
# 611                    False                 True
# 612                    False                 True
# 613                     True                False
#
# [614 rows x 2 columns]
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# ...

# %%
df1=pd.get_dummies(data['Gender'],prefix='Gender',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Gender'],axis=1)
print(data)
# Out:
#      Gender_Male
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ..           ...
# 609        False
# 610         True
# 611         True
# 612         True
# 613        False
#
# [614 rows x 1 columns]
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978      No          0      Graduate            No             2900
# 610  LP002979     Yes         3+      Graduate            No             4106
# ...

# %%
df1=pd.get_dummies(data['Married'],prefix='Married',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Married'],axis=1)
print(data)
# Out:
#      Married_Yes
# 0          False
# 1           True
# 2           True
# 3           True
# 4          False
# ..           ...
# 609        False
# 610         True
# 611         True
# 612         True
# 613        False
#
# [614 rows x 1 columns]
#       Loan_ID Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002          0      Graduate            No             5849
# 1    LP001003          1      Graduate            No             4583
# 2    LP001005          0      Graduate           Yes             3000
# 3    LP001006          0  Not Graduate            No             2583
# 4    LP001008          0      Graduate            No             6000
# ..        ...        ...           ...           ...              ...
# 609  LP002978          0      Graduate            No             2900
# 610  LP002979         3+      Graduate            No             4106
# 611  LP002983          1      Graduate            No             8072
# ...

# %%
df1=pd.get_dummies(data['Dependents'],prefix='Dependents',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Dependents'],axis=1)
print(data)
# Out:
#      Dependents_1  Dependents_2  Dependents_3+
# 0           False         False          False
# 1            True         False          False
# 2           False         False          False
# 3           False         False          False
# 4           False         False          False
# ..            ...           ...            ...
# 609         False         False          False
# 610         False         False           True
# 611          True         False          False
# 612         False          True          False
# 613         False         False          False
#
# [614 rows x 3 columns]
#       Loan_ID     Education Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0    LP001002      Graduate            No             5849                0.0
# 1    LP001003      Graduate            No             4583             1508.0
# 2    LP001005      Graduate           Yes             3000                0.0
# ...

# %%
df1=pd.get_dummies(data['Education'],prefix='Education',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Education'],axis=1)
print(data)
# Out:
#      Education_Not Graduate
# 0                     False
# 1                     False
# 2                     False
# 3                      True
# 4                     False
# ..                      ...
# 609                   False
# 610                   False
# 611                   False
# 612                   False
# 613                   False
#
# [614 rows x 1 columns]
#       Loan_ID Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002            No             5849                0.0  146.412162
# 1    LP001003            No             4583             1508.0  128.000000
# 2    LP001005           Yes             3000                0.0   66.000000
# 3    LP001006            No             2583             2358.0  120.000000
# 4    LP001008            No             6000                0.0  141.000000
# ..        ...           ...              ...                ...         ...
# ...

# %%
df1=pd.get_dummies(data['Self_Employed'],prefix='Self_Employed',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Self_Employed'],axis=1)
print(data)
# Out:
#      Self_Employed_Yes
# 0                False
# 1                False
# 2                 True
# 3                False
# 4                False
# ..                 ...
# 609              False
# 610              False
# 611              False
# 612              False
# 613               True
#
# [614 rows x 1 columns]
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0  146.412162
# 1    LP001003             4583             1508.0  128.000000
# 2    LP001005             3000                0.0   66.000000
# 3    LP001006             2583             2358.0  120.000000
# 4    LP001008             6000                0.0  141.000000
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0   71.000000
# 610  LP002979             4106                0.0   40.000000
# 611  LP002983             8072              240.0  253.000000
# ...

# %%
df1=pd.get_dummies(data['Credit_History'],prefix='Credit_History',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Credit_History'],axis=1)
print(data)
# Out:
#      Credit_History_1.0
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ..                  ...
# 609                True
# 610                True
# 611                True
# 612                True
# 613               False
#
# [614 rows x 1 columns]
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0  146.412162
# 1    LP001003             4583             1508.0  128.000000
# 2    LP001005             3000                0.0   66.000000
# 3    LP001006             2583             2358.0  120.000000
# 4    LP001008             6000                0.0  141.000000
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0   71.000000
# 610  LP002979             4106                0.0   40.000000
# 611  LP002983             8072              240.0  253.000000
# ...

# %%
df1=pd.get_dummies(data['Loan_Status (Approved)'],prefix='Loan_Status (Approved)',drop_first=True)
print(df1)
data=pd.concat([data,df1],axis=1).drop(['Loan_Status (Approved)'],axis=1)
print(data)
# Out:
#      Loan_Status (Approved)_Y
# 0                        True
# 1                       False
# 2                        True
# 3                        True
# 4                        True
# ..                        ...
# 609                      True
# 610                      True
# 611                      True
# 612                      True
# 613                     False
#
# [614 rows x 1 columns]
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0  146.412162
# 1    LP001003             4583             1508.0  128.000000
# 2    LP001005             3000                0.0   66.000000
# 3    LP001006             2583             2358.0  120.000000
# 4    LP001008             6000                0.0  141.000000
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0   71.000000
# 610  LP002979             4106                0.0   40.000000
# ...

# %%
data.columns
# Out:
# Index(['Loan_ID', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Property_Area_Semiurban', 'Property_Area_Urban',
#        'Gender_Male', 'Married_Yes', 'Dependents_1', 'Dependents_2',
#        'Dependents_3+', 'Education_Not Graduate', 'Self_Employed_Yes',
#        'Credit_History_1.0', 'Loan_Status (Approved)_Y'],
#       dtype='object')

# %%
data.columns.value_counts()
# Out:
# Loan_ID                     1
# ApplicantIncome             1
# CoapplicantIncome           1
# LoanAmount                  1
# Loan_Amount_Term            1
# Property_Area_Semiurban     1
# Property_Area_Urban         1
# Gender_Male                 1
# Married_Yes                 1
# Dependents_1                1
# Dependents_2                1
# Dependents_3+               1
# Education_Not Graduate      1
# Self_Employed_Yes           1
# Credit_History_1.0          1
# Loan_Status (Approved)_Y    1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#     Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0  LP001002             5849                0.0  146.412162             360.0
# 1  LP001003             4583             1508.0  128.000000             360.0
# 2  LP001005             3000                0.0   66.000000             360.0
# 3  LP001006             2583             2358.0  120.000000             360.0
# 4  LP001008             6000                0.0  141.000000             360.0
#
#    Property_Area_Semiurban  Property_Area_Urban  Gender_Male  Married_Yes  \
# 0                    False                 True         True        False
# 1                    False                False         True         True
# 2                    False                 True         True         True
# 3                    False                 True         True         True
# 4                    False                 True         True        False
#
# ...

# %%
data['LoanAmount'].kurtosis()
# Out:
# np.float64(10.896456468091559)

# %%
data['LoanAmount'].skew()
# Out:
# np.float64(2.726601144105299)

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='box-cox')

# %%
ltrans=trans.fit_transform(data[['LoanAmount']])
ltrans.shape
# Out:
# (614, 1)

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='yeo-johnson')

# %%
l_trans=trans.fit_transform(data[['ApplicantIncome']])
l_trans.shape
# Out:
# (614, 1)

# %%
print(pd.Series(ltrans.reshape(614,)).skew())
print(pd.Series(ltrans.reshape(614,)).kurtosis())
# Out:
# 0.030458075279689238
# 2.448058842393994

# %%
print(pd.Series(l_trans.reshape(614,)).skew())
print(pd.Series(l_trans.reshape(614,)).kurtosis())
# Out:
# -0.09294567889276603
# 4.77062663426899

# %%
sns.histplot(ltrans)
# Out:
# <Axes: ylabel='Count'>

# %%
import numpy as np

# %%
np.log(data['LoanAmount'])
# Out:
# 0      4.986426
# 1      4.852030
# 2      4.189655
# 3      4.787492
# 4      4.948760
#          ...
# 609    4.262680
# 610    3.688879
# 611    5.533389
# 612    5.231109
# 613    4.890349
# Name: LoanAmount, Length: 614, dtype: float64

# %%
data['LoanAmount']=data['LoanAmount']**(2)

# %%
data['LoanAmount']
# Out:
# 0      21436.521229
# 1      16384.000000
# 2       4356.000000
# 3      14400.000000
# 4      19881.000000
#            ...
# 609     5041.000000
# 610     1600.000000
# 611    64009.000000
# 612    34969.000000
# 613    17689.000000
# Name: LoanAmount, Length: 614, dtype: float64

# %%
co_trans=trans.fit_transform(data[['CoapplicantIncome']])
co_trans.shape
# Out:
# (614, 1)

# %%
print(pd.Series(co_trans.reshape(614,)).skew())
# Out:
# -0.14564645710551902

# %%
data['CoapplicantIncome']=data['CoapplicantIncome']**(1/2)

# %%
print(data['CoapplicantIncome'].kurtosis())
# Out:
# 2.705030329319304

# %%
lo_trans=trans.fit_transform(data[['Loan_Amount_Term']])
lo_trans.shape
# Out:
# (614, 1)

# %%
print(pd.Series(lo_trans.reshape(614,)).skew())
# Out:
# 0.3661790206730569

# %%
np.log(data['Loan_Amount_Term'])
# Out:
# 0      5.886104
# 1      5.886104
# 2      5.886104
# 3      5.886104
# 4      5.886104
#          ...
# 609    5.886104
# 610    5.192957
# 611    5.886104
# 612    5.886104
# 613    5.886104
# Name: Loan_Amount_Term, Length: 614, dtype: float64

# %%
print(data['Loan_Amount_Term'].kurtosis())
# Out:
# 6.673473692814259
